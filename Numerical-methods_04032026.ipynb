# %%
TEXT = """
Проект направлен на разработку MVP цифровой платформы для создания персонализированных ИИ-аватаров (цифровых двойников), способных воспроизводить голос и внешний образ пользователя на основе технологий генеративного искусственного интеллекта с системой верификации личности и защиты биометрических данных.
Цель реализуемого проекта — разработка и запуск прототипа безопасной платформы генерации цифровых двойников, обеспечивающей контроль использования биометрических данных и предотвращение мошеннических сценариев применения синтетического медиаконтента.
Задачи проекта включают разработку архитектуры платформы, создание модулей синтеза речи и генерации видео-аватара, внедрение системы цифровой маркировки ИИ-контента, разработку механизма согласия на обработку биометрических данных и проведение тестирования MVP.
Конечный результат — функционирующий прототип SaaS-платформы для создания цифровых AI-ассистентов с базовыми функциями генерации аудио- и видеоконтента.
Области применения: цифровой контент, онлайн-образование, маркетинг, корпоративные коммуникации.
Целевая аудитория: блогеры, преподаватели, создатели онлайн-курсов, маркетологи, представители малого и среднего бизнеса.

"""

arr = [i.strip() for i in TEXT]
len(arr)
# Out:
# 1193
